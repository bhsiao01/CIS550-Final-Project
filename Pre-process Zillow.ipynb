# %%
import pandas as pd
import numpy as np
#useful resource: https://stackoverflow.com/questions/28654047/pandas-convert-some-columns-into-rows

# %%
cities = pd.read_csv('City_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_mon.csv')
cities
# Out:
#        RegionID  SizeRank   RegionName RegionType StateName State  \
# 0          6181         0     New York       City        NY    NY
# 1         12447         1  Los Angeles       City        CA    CA
# 2         39051         2      Houston       City        TX    TX
# 3         17426         3      Chicago       City        IL    IL
# 4          6915         4  San Antonio       City        TX    TX
# ...         ...       ...          ...        ...       ...   ...
# 25661     12973     29449    Newcastle       City        NE    NE
# 25662     29846     29449      Barwick       City        GA    GA
# 25663     51148     29449    Broad Top       City        PA    PA
# 25664    232332     29449         Cool       City        TX    TX
# 25665      5133     29449    Hermitage       City        MO    MO
#
#                                   Metro          CountyName  1996-01-31  \
# 0           New York-Newark-Jersey City       Queens County    192871.0
# ...

# %%
dates = cities.columns[8:]
dates
# Out:
# Index(['1996-01-31', '1996-02-29', '1996-03-31', '1996-04-30', '1996-05-31',
#        '1996-06-30', '1996-07-31', '1996-08-31', '1996-09-30', '1996-10-31',
#        ...
#        '2020-04-30', '2020-05-31', '2020-06-30', '2020-07-31', '2020-08-31',
#        '2020-09-30', '2020-10-31', '2020-11-30', '2020-12-31', '2021-01-31'],
#       dtype='object', length=301)

# %%
clean_cities = cities.melt(id_vars=cities.columns[0:8], 
        var_name="Date", 
        value_name="Value")

# %%
clean_cities.sort_values(['RegionID','Date'],inplace=True)

# %%
clean_cities
# Out:
#          RegionID  SizeRank RegionName RegionType StateName State  \
# 9915         3300     10860   Aberdeen       City        ID    ID
# 35581        3300     10860   Aberdeen       City        ID    ID
# 61247        3300     10860   Aberdeen       City        ID    ID
# 86913        3300     10860   Aberdeen       City        ID    ID
# 112579       3300     10860   Aberdeen       City        ID    ID
# ...           ...       ...        ...        ...       ...   ...
# 7603291    760887      6571     Berlin       City        NJ    NJ
# 7628957    760887      6571     Berlin       City        NJ    NJ
# 7654623    760887      6571     Berlin       City        NJ    NJ
# 7680289    760887      6571     Berlin       City        NJ    NJ
# 7705955    760887      6571     Berlin       City        NJ    NJ
#
#                                   Metro      CountyName        Date     Value
# 9915                          Blackfoot  Bingham County  1996-01-31       NaN
# ...

# %%
clean_cities[clean_cities['Value'].isna()]['RegionName'].value_counts()
# Out:
# Franklin      2318
# Greenville    2070
# Ashland       1870
# Florence      1818
# Jackson       1766
#               ...
# Weirsdale        1
# Redvale          1
# Olcott           1
# Maribel          1
# Vine Grove       1
# Name: RegionName, Length: 11149, dtype: int64

# %%
clean_cities.to_csv('Zillow City Data.csv')
