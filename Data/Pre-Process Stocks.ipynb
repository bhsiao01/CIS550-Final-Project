# %%
import os

# %%
path = 'stocks/'
files = os.listdir(path)
i = 0

# %%
for index, file in enumerate(files):
    os.rename(os.path.join(path, file), os.path.join(path, ''.join(['stock.part_', str(index).zfill(4)])))
    print(os.path.join(path, ''.join(['stock.part_', str(index).zfill(4)])))
# Out:
# stocks/stock.part_0000
# stocks/stock.part_0001
# stocks/stock.part_0002
# stocks/stock.part_0003
# stocks/stock.part_0004
# stocks/stock.part_0005
# stocks/stock.part_0006
# stocks/stock.part_0007
# stocks/stock.part_0008
# stocks/stock.part_0009
# stocks/stock.part_0010
# stocks/stock.part_0011
# stocks/stock.part_0012
# stocks/stock.part_0013
# stocks/stock.part_0014
# stocks/stock.part_0015
# stocks/stock.part_0016
# stocks/stock.part_0017
# stocks/stock.part_0018
# stocks/stock.part_0019
# stocks/stock.part_0020
# stocks/stock.part_0021
# stocks/stock.part_0022
# stocks/stock.part_0023
# stocks/stock.part_0024
# stocks/stock.part_0025
# stocks/stock.part_0026
# stocks/stock.part_0027
# stocks/stock.part_0028
# stocks/stock.part_0029
# stocks/stock.part_0030
# stocks/stock.part_0031
# stocks/stock.part_0032
# stocks/stock.part_0033
# stocks/stock.part_0034
# stocks/stock.part_0035
# stocks/stock.part_0036
# stocks/stock.part_0037
# stocks/stock.part_0038
# stocks/stock.part_0039
# ...

# %%
# Out:
# 5884
